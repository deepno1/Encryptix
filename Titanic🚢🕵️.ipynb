# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Exploretry Data Analysis
#
#
#   - Univariate Analysis

# %% [markdown]
# # Conclusion
#
# - max age is 20-35 & almost normal distribution & 19% missing values
# - fare col highly skewed & it has mix value not indiv person value & we need to feature individual value col

# %% [markdown]
# # Columns types
# -Numarical:- PassengerId,Age,Fare
#
# -Categorycal:- Survived,Pclass,Sex,SibSp,Parch,Embarked.
#
# -Mixed:- Name,Cabin,Ticket

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind='hist',bins=16)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Age']>65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
df['Age'].isnull().sum()/len(df['Age'])*100
# Out:
# 19.865319865319865

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind='hist',bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Fare']>230]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 438          439         0       1
# 679          680         1       1
# 737          738         1       1
# 742          743         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 27                    Fortune, Mr. Charles Alexander    male  19.0      3
# 88                        Fortune, Miss. Mabel Helen  female  23.0      3
# 118                         Baxter, Mr. Quigg Edmond    male  24.0      0
# 258                                 Ward, Miss. Anna  female  35.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 311                       Ryerson, Miss. Emily Borie  female  18.0      2
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %% [markdown]
# # Conclution
#
# - 61%+ people die
# - more people in pc 1 instead fo pc 2
# - 64%+ males
# - more people traval alon
# - more with no parch
# - 72%+ people from 'S' & 2 nan values
# - merge parch and sibsp columns
# - create col for alone

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].isnull().sum()
# Out:
# 0

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SibSp'>

# %%
df['SibSp'].value_counts().plot(kind = 'pie' ,autopct = '%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['SibSp'].isnull().sum()
# Out:
# 0

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df['Parch'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Parch'>

# %%
df['Parch'].value_counts().plot(kind = 'pie' ,autopct = '%0.2f%%' )
# Out:
# <Axes: ylabel='count'>

# %%
df['Parch'].isnull().sum()
# Out:
# 0

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind = 'pie', autopct = '%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %% [markdown]
# # Bivariate Analysis
# - # Columns types
#    - Numarical:- PassengerId,Age,Fare
#
#    - Categorycal:- Survived,Pclass,Sex,SibSp,Parch,Embarked.
#
#    - Mixed:- Name,Cabin,Ticket

# %% [markdown]
# # Conclutions
# - pc 3 is risky to traval & pc1 is safe to travall
# - High chances to Survived for female
# - High chances to Survived for 0-16 age & low for 20-40 age
# - High chances to Survived for 'c' & low for 's'
# - pc 1 class has 40-80 age people and 50% pec from 'C'

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100
# Out:
# Pclass            1          2          3
# Survived
# 0         37.037037  52.717391  75.763747
# 1         62.962963  47.282609  24.236253

# %%
sb.heatmap(pd.crosstab(df['Survived'],df['Pclass'],normalize='columns')*100);

# %%
pd.crosstab(df['Survived'],df['Sex'],normalize='columns')*100
# Out:
# Sex          female       male
# Survived
# 0         25.796178  81.109185
# 1         74.203822  18.890815

# %%
sb.heatmap(pd.crosstab(df['Survived'],df['Sex'],normalize='columns')*100);

# %%
df[df['Survived'] == 1]['Age'].plot(kind = 'kde', label = 'Survived')
df[df['Survived'] == 0]['Age'].plot(kind = 'kde', label = 'Not Survived')
plt.legend()
plt.show()

# %%
pd.crosstab(df['Survived'],df['Embarked'], normalize = 'columns')*100
# Out:
# Embarked          C          Q          S
# Survived
# 0         44.642857  61.038961  66.304348
# 1         55.357143  38.961039  33.695652

# %%
sb.heatmap(pd.crosstab(df['Survived'],df['Embarked'], normalize = 'columns')*100);

# %%
pd.crosstab(df['Pclass'],df['Embarked'], normalize = 'columns')*100
# Out:
# Embarked          C          Q          S
# Pclass
# 1         50.595238   2.597403  19.720497
# 2         10.119048   3.896104  25.465839
# 3         39.285714  93.506494  54.813665

# %%
pd.crosstab(df['Pclass'],df['Sex'], normalize = 'columns')*100
# Out:
# Sex        female       male
# Pclass
# 1       29.936306  21.143847
# 2       24.203822  18.717504
# 3       45.859873  60.138648

# %%
df[df['Pclass'] == 1]['Age'].plot(kind = 'kde', label='p1')
df[df['Pclass'] == 2]['Age'].plot(kind = 'kde', label='p2')
df[df['Pclass'] == 3]['Age'].plot(kind = 'kde', label='p3')
plt.legend()
plt.show()

# %%
df[df['Sex'] == 'male']['Age'].plot(kind = 'kde', label='male')
df[df['Sex'] == 'female']['Age'].plot(kind = 'kde', label='female')
plt.legend()
plt.show()

# %%
pd.crosstab(df['Sex'],df['Embarked'], normalize = 'columns')*100
# Out:
# Embarked          C          Q          S
# Sex
# female    43.452381  46.753247  31.521739
# male      56.547619  53.246753  68.478261

# %%
df[df['Embarked'] == "S"]['Age'].plot(kind = 'kde', label='S')
df[df['Embarked'] == "Q"]['Age'].plot(kind = 'kde', label='Q')
df[df['Embarked'] == "C"]['Age'].plot(kind = 'kde', label='C')
plt.legend()
plt.show()

# %%
df.reset_index(inplace=True)

# %%
df.drop('index',axis=1,inplace=True)

# %%
# family size
l=[]
for i in range(0,891):
    r=df['SibSp'].loc[i]+df['Parch'].loc[i]+1
    l.append(r)

# %%
df['family_size'] = l

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
k=[]
for i in range(0,891):
    d=df['Fare'].loc[i]/df['family_size'].loc[i]
    k.append(d)

# %%
df['individual_fare']=k

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  family_size  \
# 0      0         A/5 21171   7.2500   NaN        S            2
# 1      0          PC 17599  71.2833   C85        C            2
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1
# ...

# %%
df[df['Survived'] == 0]['individual_fare'].plot(kind = 'kde', label = 'not survived')
df[df['Survived'] == 1]['individual_fare'].plot(kind = 'kde', label = 'survived')
plt.legend()
plt.show()

# %%
df[df['Pclass'] == 1]['individual_fare'].plot(kind = 'kde', label = 'p1')
df[df['Pclass'] == 2]['individual_fare'].plot(kind = 'kde', label = 'p2')
df[df['Pclass'] == 3]['individual_fare'].plot(kind = 'kde', label = 'p3')
plt.legend()
plt.show()

# %%
df[df['Embarked'] == "S"]['individual_fare'].plot(kind = 'kde', label='S')
df[df['Embarked'] == "Q"]['individual_fare'].plot(kind = 'kde', label='Q')
df[df['Embarked'] == "C"]['individual_fare'].plot(kind = 'kde', label='C')
plt.legend()
plt.show()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  family_size  \
# 0      0         A/5 21171   7.2500   NaN        S            2
# 1      0          PC 17599  71.2833   C85        C            2
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1
# ...

# %%
df['family_size'].value_counts()
# Out:
# family_size
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64

# %%
def family(num):
    
    if num == 1:
        return 'alone'
    elif num > 1 and num < 5:
        return 'small'
    else:
        return 'large'

# %%
df['family_size'] = df['family_size'].apply(family)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked family_size  \
# 0      0         A/5 21171   7.2500   NaN        S       small
# 1      0          PC 17599  71.2833   C85        C       small
# 2      0  STON/O2. 3101282   7.9250   NaN        S       alone
# ...

# %%
pd.crosstab(df['Survived'],df['family_size'], normalize = 'columns')*100
# Out:
# family_size      alone      large      small
# Survived
# 0            69.646182  83.870968  42.123288
# 1            30.353818  16.129032  57.876712

# %%
sb.heatmap(pd.crosstab(df['Survived'],df['family_size'], normalize = 'columns')*100)
# Out:
# <Axes: xlabel='family_size', ylabel='Survived'>

# %%
df['deck'] = df['Cabin'].str[0]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked family_size  \
# 0      0         A/5 21171   7.2500   NaN        S       small
# 1      0          PC 17599  71.2833   C85        C       small
# 2      0  STON/O2. 3101282   7.9250   NaN        S       alone
# ...

# %%
pd.crosstab(df['Survived'],df['deck'], normalize = 'columns')*100
# Out:
# deck              A          B          C          D     E          F     G  \
# Survived
# 0         53.333333  25.531915  40.677966  24.242424  25.0  38.461538  50.0
# 1         46.666667  74.468085  59.322034  75.757576  75.0  61.538462  50.0
#
# deck          T
# Survived
# 0         100.0
# 1           0.0

# %%
pd.crosstab(df['Pclass'],df['deck'], normalize = 'columns')*100
# Out:
# deck        A      B      C          D       E          F      G      T
# Pclass
# 1       100.0  100.0  100.0  87.878788  78.125   0.000000    0.0  100.0
# 2         0.0    0.0    0.0  12.121212  12.500  61.538462    0.0    0.0
# 3         0.0    0.0    0.0   0.000000   9.375  38.461538  100.0    0.0

# %%
pd.crosstab(df['family_size'],df['deck'], normalize = 'columns')*100
# Out:
# deck            A          B          C          D       E          F      G  \
# family_size
# alone        80.0  46.808511  37.288136  39.393939  53.125  53.846154    0.0
# large         0.0   4.255319   6.779661   0.000000   0.000   0.000000    0.0
# small        20.0  48.936170  55.932203  60.606061  46.875  46.153846  100.0
#
# deck             T
# family_size
# alone        100.0
# large          0.0
# small          0.0

# %%
sb.heatmap(pd.crosstab(df['Survived'],df['deck'], normalize = 'columns')*100)
# Out:
# <Axes: xlabel='deck', ylabel='Survived'>

# %%
sb.heatmap(pd.crosstab(df['Pclass'],df['deck'], normalize = 'columns')*100)
# Out:
# <Axes: xlabel='deck', ylabel='Pclass'>

# %%
sb.heatmap(pd.crosstab(df['family_size'],df['deck'], normalize = 'columns')*100)
# Out:
# <Axes: xlabel='deck', ylabel='family_size'>

# %%
df[df['deck'] == 'A']['Age'].plot(kind = 'kde', label = 'A')
df[df['deck'] == 'B']['Age'].plot(kind = 'kde', label = 'B')
df[df['deck'] == 'C']['Age'].plot(kind = 'kde', label = 'C')
df[df['deck'] == 'D']['Age'].plot(kind = 'kde', label = 'D')
df[df['deck'] == 'E']['Age'].plot(kind = 'kde', label = 'E')
df[df['deck'] == 'F']['Age'].plot(kind = 'kde', label = 'F')
df[df['deck'] == 'G']['Age'].plot(kind = 'kde', label = 'G')
plt.legend()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      891 non-null    int64
#  1   Survived         891 non-null    int64
#  2   Pclass           891 non-null    int64
#  3   Name             891 non-null    object
#  4   Sex              891 non-null    object
#  5   Age              714 non-null    float64
#  6   SibSp            891 non-null    int64
#  7   Parch            891 non-null    int64
#  8   Ticket           891 non-null    object
#  9   Fare             891 non-null    float64
#  10  Cabin            204 non-null    object
#  11  Embarked         889 non-null    object
#  12  family_size      891 non-null    object
#  13  individual_fare  891 non-null    float64
#  14  deck             204 non-null    object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 104.5+ KB

# %%
df.drop(columns = ['Cabin'], inplace = True)

# %%
df.drop(columns = ['deck'], inplace = True)

# %%
df[df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked family_size  \
# 61   female  38.0      0      0  113572  80.0      NaN       alone
# 829  female  62.0      0      0  113572  80.0      NaN       alone
#
#      individual_fare
# 61              80.0
# 829             80.0

# %%
df['Embarked'].fillna('S', inplace = True)

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
a = np.random.randint(df['Age'].mean()-df['Age'].std(), df['Age'].mean()+df['Age'].std(), 177)

# %%
ind = df[df['Age'].isnull()].index

# %%
df.loc[ind,"Age"] = a

# %%
df.isnull().sum()
# Out:
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age                0
# SibSp              0
# Parch              0
# Ticket             0
# Fare               0
# Embarked           0
# family_size        0
# individual_fare    0
# dtype: int64

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PassengerId      891 non-null    int64
#  1   Survived         891 non-null    int64
#  2   Pclass           891 non-null    int64
#  3   Name             891 non-null    object
#  4   Sex              891 non-null    object
#  5   Age              891 non-null    int32
#  6   SibSp            891 non-null    int64
#  7   Parch            891 non-null    int64
#  8   Ticket           891 non-null    object
#  9   Fare             891 non-null    float64
#  10  Embarked         891 non-null    object
#  11  family_size      891 non-null    object
#  12  individual_fare  891 non-null    float64
# dtypes: float64(2), int32(1), int64(5), object(5)
# memory usage: 87.1+ KB

# %%
df.groupby(['Sex'])['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df.groupby(['family_size'])['Survived'].mean()*100
# Out:
# family_size
# alone    30.353818
# large    16.129032
# small    57.876712
# Name: Survived, dtype: float64

# %%
df.drop(['SibSp','Parch','individual_fare'],axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   Ticket       891 non-null    object
#  7   Fare         891 non-null    float64
#  8   Embarked     891 non-null    object
#  9   family_size  891 non-null    object
# dtypes: float64(1), int32(1), int64(3), object(5)
# memory usage: 66.3+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  \
# 0                            Braund, Mr. Owen Harris    male   22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2                             Heikkinen, Miss. Laina  female   26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4                           Allen, Mr. William Henry    male   35
#
#              Ticket     Fare Embarked family_size
# 0         A/5 21171   7.2500        S       small
# 1          PC 17599  71.2833        C       small
# 2  STON/O2. 3101282   7.9250        S       alone
# 3            113803  53.1000        S       small
# 4            373450   8.0500        S       alone

# %%
sb.distplot(df[df['Survived'] == 0]['Fare'], label = 'not Survived')
sb.distplot(df[df['Survived'] == 1]['Fare'], label = 'Survived')
plt.legend()
plt.show()
# Out:
# C:\Users\Jhanvi\AppData\Local\Temp\ipykernel_96668\893258170.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df[df['Survived'] == 0]['Fare'], label = 'not Survived')
# C:\Users\Jhanvi\AppData\Local\Temp\ipykernel_96668\893258170.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df.drop(['PassengerId','Name','Ticket'],axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex  Age     Fare Embarked family_size
# 0         0       3    male   22   7.2500        S       small
# 1         1       1  female   38  71.2833        C       small
# 2         1       3  female   26   7.9250        S       alone
# 3         1       1  female   35  53.1000        S       small
# 4         0       3    male   35   8.0500        S       alone

# %%
df = pd.get_dummies(data = df, columns = ['Pclass','Sex','Embarked','family_size'])

# %%
df = df.sample(df.shape[0])

# %%
x = df.iloc[:,1:].values
y = df.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2 , random_state = 1282)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pre = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test , y_pre)

# %%
accuracy
# Out:
# 0.8547486033519553

# %%
model1 = LogisticRegression()

model1.fit(x_train, y_train)
# Out:
# C:\Users\Jhanvi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pre1 = model1.predict(x_test)
score = accuracy_score(y_test, y_pre1) 
score
# Out:
# 0.8994413407821229

# %%
col = df.drop(['Survived'], axis = 1).columns.tolist()

# %%
x_train.shape
# Out:
# (712, 13)

# %%
import pickle
pickle.dump(model1, open('Titanic.pkl','wb'))

# %%
pickle.dump(col, open('Titanic_cols.pkl','wb'))

# %%
col
# Out:
# ['Age',
#  'Fare',
#  'Pclass_1',
#  'Pclass_2',
#  'Pclass_3',
#  'Sex_female',
#  'Sex_male',
#  'Embarked_C',
#  'Embarked_Q',
#  'Embarked_S',
#  'family_size_alone',
#  'family_size_large',
#  'family_size_small']

# %%
a = []
for i in range(5000):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2 , random_state = i)
    model1 = LogisticRegression()
    model1.fit(x_train, y_train)
    y_pre1 = model1.predict(x_test)
    accuracy = accuracy_score(y_test , y_pre1)
    a.append(accuracy)
# Out:
# C:\Users\Jhanvi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Jhanvi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
max(a)
# Out:
# 0.8994413407821229

# %%
np.argmax(a)
# Out:
# 1282

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("IMDb Movies India.csv" , encoding= 'latin-1')

# %% [markdown]
# # Data Cleaning

# %%
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Genre'] = df['Genre'].str.split(',')

# %%
df = df.explode('Genre')

# %%
df.head()
# Out:
#                                  Name    Year Duration     Genre  Rating  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min     Drama     7.0
# 3                             #Yaaram  (2019)  110 min    Comedy     4.4
# 3                             #Yaaram  (2019)  110 min   Romance     4.4
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min    Comedy     4.7
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min     Drama     4.7
#
#   Votes       Director       Actor 1                 Actor 2          Actor 3
# 1     8  Gaurav Bakshi  Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3    35     Ovais Khan       Prateik              Ishita Raj  Siddhant Kapoor
# 3    35     Ovais Khan       Prateik              Ishita Raj  Siddhant Kapoor
# 5   827   Rahul Rawail    Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 5   827   Rahul Rawail    Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor

# %%
df['Genre'] = df['Genre'].str.strip()

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Comedy', 'Romance', 'Musical', 'War', 'Horror',
#        'Mystery', 'Thriller', 'Action', 'Crime', 'History', 'Adventure',
#        'Sci-Fi', 'Sport', 'Biography', 'Family', 'Fantasy', 'Documentary',
#        'Music', 'Animation', 'News', 'Western'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11979 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11979 non-null  object
#  1   Year      11979 non-null  object
#  2   Duration  11979 non-null  object
#  3   Genre     11979 non-null  object
#  4   Rating    11979 non-null  float64
#  5   Votes     11979 non-null  object
#  6   Director  11979 non-null  object
#  7   Actor 1   11979 non-null  object
#  8   Actor 2   11979 non-null  object
#  9   Actor 3   11979 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df['Duration'] = df['Duration'].str.replace('min','')

# %%
df['Duration'] = df['Duration'].astype(int)

# %%
df['Votes'] = df['Votes'].str.replace(',','')

# %%
df['Votes'] = df['Votes'].str.strip()

# %%
df['Votes'] = df['Votes'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11979 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11979 non-null  object
#  1   Year      11979 non-null  object
#  2   Duration  11979 non-null  int32
#  3   Genre     11979 non-null  object
#  4   Rating    11979 non-null  float64
#  5   Votes     11979 non-null  int32
#  6   Director  11979 non-null  object
#  7   Actor 1   11979 non-null  object
#  8   Actor 2   11979 non-null  object
#  9   Actor 3   11979 non-null  object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 935.9+ KB

# %% [markdown]
# # EDA

# %%
sb.scatterplot( x = 'Duration' , y = 'Rating' , data = df)
# Out:
# <Axes: xlabel='Duration', ylabel='Rating'>

# %%
df['Duration'].corr(df['Rating'])
# Out:
# 0.033127518056160855

# %%
sb.barplot(x = df['Genre'], y = df['Rating'])
plt.xticks(rotation = 65)
plt.show()

# %%
sb.boxplot(x = df['Genre'], y = df['Rating'])
plt.xticks(rotation = 65)
plt.show()

# %%
sb.scatterplot( x = 'Votes' , y = 'Rating' , data = df)
# Out:
# <Axes: xlabel='Votes', ylabel='Rating'>

# %%
df['Votes'].corr(df['Rating'])
# Out:
# 0.15655495253222998

# %%
fig = plt.subplots(figsize=(15, 30))
sb.barplot(x = df['Rating'], y = df['Director'])
plt.xticks()
plt.show()

# %%
fig = plt.subplots(figsize=(15, 30))
sb.barplot(x = df['Rating'], y = df['Actor 1'])
plt.xticks()
plt.show()

# %%
fig = plt.subplots(figsize=(15, 20))
sb.barplot(x = df['Rating'], y = df['Actor 2'])
plt.xticks()
plt.show()

# %%
fig = plt.subplots(figsize=(15, 30))
sb.barplot(x = df['Rating'], y = df['Actor 3'])
plt.xticks()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11979 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11979 non-null  object
#  1   Year      11979 non-null  object
#  2   Duration  11979 non-null  int32
#  3   Genre     11979 non-null  object
#  4   Rating    11979 non-null  float64
#  5   Votes     11979 non-null  int32
#  6   Director  11979 non-null  object
#  7   Actor 1   11979 non-null  object
#  8   Actor 2   11979 non-null  object
#  9   Actor 3   11979 non-null  object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 935.9+ KB

# %% [markdown]
# # Romove Outlires

# %%
df['Duration'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Duration'].skew()
# Out:
# -0.020020145755258976

# %%
df['Rating'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Rating'].skew()
# Out:
# -0.4439913734008175

# %%
df['Rating'].plot(kind = 'box')
plt.show()

# %%
#finding IQR
p25 = df['Rating'].quantile(0.25)
p75 = df['Rating'].quantile(0.75)

# %%
iqr = p75 - p25
iqr
# Out:
# 1.9000000000000004

# %%
upper_limit = p75 + 1.5 * iqr
lower_limit = p25 - 1.5 * iqr

# %%
upper_limit
# Out:
# 9.75

# %%
lower_limit
# Out:
# 2.1499999999999995

# %%
df = df[df['Rating'] > lower_limit]

# %%
df = df[df['Rating'] < upper_limit]

# %%
df['Rating'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11919 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11919 non-null  object
#  1   Year      11919 non-null  object
#  2   Duration  11919 non-null  int32
#  3   Genre     11919 non-null  object
#  4   Rating    11919 non-null  float64
#  5   Votes     11919 non-null  int32
#  6   Director  11919 non-null  object
#  7   Actor 1   11919 non-null  object
#  8   Actor 2   11919 non-null  object
#  9   Actor 3   11919 non-null  object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 931.2+ KB

# %%
df['Votes'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
#finding IQR
p25 = df['Votes'].quantile(0.25)
p75 = df['Votes'].quantile(0.75)

# %%
iqr = p75 - p25
iqr
# Out:
# 1404.5

# %%
upper_limit = p75 + 1.5 * iqr
lower_limit = p25 - 1.5 * iqr

# %%
upper_limit
# Out:
# 3552.25

# %%
df = df[df['Votes'] < upper_limit]

# %%
df['Votes'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10055 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      10055 non-null  object
#  1   Year      10055 non-null  object
#  2   Duration  10055 non-null  int32
#  3   Genre     10055 non-null  object
#  4   Rating    10055 non-null  float64
#  5   Votes     10055 non-null  int32
#  6   Director  10055 non-null  object
#  7   Actor 1   10055 non-null  object
#  8   Actor 2   10055 non-null  object
#  9   Actor 3   10055 non-null  object
# dtypes: float64(1), int32(2), object(7)
# memory usage: 785.5+ KB

# %%
df['Genre'].nunique()
# Out:
# 22

# %%
df['Year'] = df['Year'].str.replace('(','')
df['Year'] = df['Year'].str.replace(')','')
df['Year'] = df['Year'].str.strip()

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10055 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      10055 non-null  object
#  1   Year      10055 non-null  int32
#  2   Duration  10055 non-null  int32
#  3   Genre     10055 non-null  object
#  4   Rating    10055 non-null  float64
#  5   Votes     10055 non-null  int32
#  6   Director  10055 non-null  object
#  7   Actor 1   10055 non-null  object
#  8   Actor 2   10055 non-null  object
#  9   Actor 3   10055 non-null  object
# dtypes: float64(1), int32(3), object(6)
# memory usage: 746.3+ KB

# %% [markdown]
# # Feature Engineering

# %%
genre_mean_rating = df.groupby('Genre')['Rating'].transform('mean')
df['Genre_mean_rating'] = genre_mean_rating

director_mean_rating = df.groupby('Director')['Rating'].transform('mean')
df['Director_encoded'] = director_mean_rating

actor1_mean_rating = df.groupby('Actor 1')['Rating'].transform('mean')
df['Actor1_encoded'] = actor1_mean_rating

actor2_mean_rating = df.groupby('Actor 2')['Rating'].transform('mean')
df['Actor2_encoded'] = actor2_mean_rating

actor3_mean_rating = df.groupby('Actor 3')['Rating'].transform('mean')
df['Actor3_encoded'] = actor3_mean_rating

# %%
df.sample(5)
# Out:
#                           Name  Year  Duration    Genre  Rating  Votes  \
# 2933                      Chef  2017       133    Drama     5.7   2229
# 14318         Thodisi Bewafaii  1980       150    Drama     5.9    101
# 1266              Arjun Pandit  1999       150  Romance     5.2    797
# 1501   Baankey Ki Crazy Baraat  2015       138   Comedy     6.2    356
# 10303                 Offshore  2006        92    Drama     6.3     20
#
#               Director        Actor 1                  Actor 2  \
# 2933        Raja Menon  Saif Ali Khan               Padmapriya
# 14318  Esmayeel Shroff  Rajesh Khanna             Shabana Azmi
# 1266      Rahul Rawail     Sunny Deol              Juhi Chawla
# 1501        Aijaz Khan   Rajpal Yadav               Tia Bajpai
# 10303   Diane Cheklich  Diane Allemon  Ratnabali Bhattacharjee
#
#               Actor 3  Genre_mean_rating  Director_encoded  Actor1_encoded  \
# 2933      Svar Kamble           5.948585          6.250000        5.137500
# ...

# %%
X = df[[ 'Year', 'Votes', 'Duration', 'Genre_mean_rating','Director_encoded','Actor1_encoded', 'Actor2_encoded', 'Actor3_encoded']]
y = df['Rating']

# %% [markdown]
# # Model Creation

# %%
from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.linear_model import LinearRegression

from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, r2_score
     
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2 , random_state = 570)

# %%
Model = LinearRegression()

Model.fit(X_train,y_train)

Model_pred = Model.predict(X_test)


print('Mean squared error: ',mean_squared_error(y_test, Model_pred))
print('Mean absolute error: ',mean_absolute_error(y_test, Model_pred))
print('R2 score: ',r2_score(y_test, Model_pred)*100)
# Out:
# Mean squared error:  0.272230549318915
# Mean absolute error:  0.3940298534385079
# R2 score:  84.94960599423447

# %% [markdown]
# # Hyperparameter Tuning

# %%
score = []
for i in range(1000):
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=i)
    Model = LinearRegression()

    Model.fit(X_train,y_train)

    Model_pred = Model.predict(X_test)
    
    score.append(r2_score(y_test, Model_pred)*100)

# %%
score[np.argmax(score)]
# Out:
# 84.94960599423447

# %%
np.argmax(score)
# Out:
# 570

# %%
# test
data = {'Year': [2017], 'Votes': [3552], 'Duration': [120], 'Genre_mean_rating': [6.5], 'Director_encoded': [8], 'Actor1_encoded': [9], 'Actor2_encoded': [7.5], 'Actor3_encoded': [4.5]}
test = pd.DataFrame(data)

# %%
test
# Out:
#    Year  Votes  Duration  Genre_mean_rating  Director_encoded  Actor1_encoded  \
# 0  2017   3552       120                6.5                 8               9
#
#    Actor2_encoded  Actor3_encoded
# 0             7.5             4.5

# %%
predicted = Model.predict(test)
print("Predicted Rating:", predicted[0])
# Out:
# Predicted Rating: 8.041863345098452
